# %%
import pandas as pd
import sqlite3

conn = sqlite3.connect("../data/db/mutualfund.db")

# %%
query = """
SELECT COUNT(*)
FROM customers;
"""
pd.read_sql(query,conn)
# Out:
#    COUNT(*)
# 0        40

# %%
query = """
SELECT COUNT(*)
FROM navhistory;
"""

pd.read_sql(query,conn)
# Out:
#    COUNT(*)
# 0     46000

# %%
query = """
SELECT COUNT(*)
FROM aumbyfh;
"""

pd.read_sql(query,conn)
# Out:
#    COUNT(*)
# 0        90

# %%
query = """
SELECT COUNT(*)
FROM sipinflow;
"""

pd.read_sql(query,conn)
# Out:
#    COUNT(*)
# 0        48

# %%
query = """
SELECT COUNT(*)
FROM catinflow;
"""

pd.read_sql(query,conn)
# Out:
#    COUNT(*)
# 0       144

# %%
query = """
SELECT COUNT(*)
FROM foliocount;
"""

pd.read_sql(query,conn)
# Out:
#    COUNT(*)
# 0        21

# %%
query = """
SELECT COUNT(*)
FROM schemeperf;
"""

pd.read_sql(query,conn)
# Out:
#    COUNT(*)
# 0        40

# %%
query = """
SELECT COUNT(*)
FROM transactions;
"""

pd.read_sql(query,conn)
# Out:
#    COUNT(*)
# 0     32778

# %%
query = """
SELECT COUNT(*)
FROM pholdings;
"""

pd.read_sql(query,conn)
# Out:
#    COUNT(*)
# 0       322

# %%
query = """
SELECT COUNT(*)
FROM benchmarks;
"""

pd.read_sql(query,conn)
# Out:
#    COUNT(*)
# 0      8050
