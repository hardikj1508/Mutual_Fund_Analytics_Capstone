# %%
import sqlite3
import pandas as pd

nav = pd.read_csv(
    "../data/processed/02_nav_history_cleaned.csv"
)

conn = sqlite3.connect(
    "../database/mutualfund.db"
)

query = """
SELECT COUNT(*)
FROM fact_nav
"""

pd.read_sql(query, conn)
# Out:
#    COUNT(*)
# 0     46000

# %%
len(nav)
# Out:
# 46000
